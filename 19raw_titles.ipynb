# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\raw_titles.csv")

# %%
data
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# ...

# %%
data['genres']=data['genres'].str.replace('[','')
data['genres']=data['genres'].str.replace(']','')
data['genres']=data['genres'].str.replace("''",'')
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_1280\3515443290.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['genres']=data['genres'].str.replace('[','')
# C:\Users\raisu\AppData\Local\Temp\ipykernel_1280\3515443290.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['genres']=data['genres'].str.replace(']','')

# %%
data['genres']=data['genres'].str.replace("'",'')

# %%
data['genres']
# Out:
# 0                   documentation
# 1                    crime, drama
# 2                 comedy, fantasy
# 3                          comedy
# 4                          horror
#                   ...
# 5801               romance, drama
# 5802         music, documentation
# 5803                family, drama
# 5804             action, thriller
# 5805    family, comedy, animation
# Name: genres, Length: 5806, dtype: object

# %%
data[data['genres'].str.contains('comedy')]
# Out:
#       index         id                                      title   type  \
# 2         2   tm127384            Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                              Life of Brian  MOVIE
# 5         5    ts22164               Monty Python's Flying Circus   SHOW
# 12       12    tm69778  Lupin the Third: The Castle of Cagliostro  MOVIE
# 13       13    tm69997             Richard Pryor: Live in Concert  MOVIE
# ...     ...        ...                                        ...    ...
# 5795   5795   tm878575                        The Heartbreak Club  MOVIE
# 5797   5797   tm985215                       Princess 'Daya'Reese  MOVIE
# 5799   5799   ts307884                                 HQ Barbers   SHOW
# 5800   5800  tm1040816                Momshies! Your Soul is Mine  MOVIE
# 5805   5805   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# ...

# %%
data["age_certification"].value_counts()
# Out:
# TV-MA    841
# R        575
# TV-14    470
# PG-13    440
# PG       246
# TV-PG    186
# G        131
# TV-Y7    112
# TV-Y     105
# TV-G      76
# NC-17     14
# Name: age_certification, dtype: int64

# %%
data['age_certification'].isnull().sum()
# Out:
# 2610

# %%
data.groupby('type').count()['title']
# Out:
# type
# MOVIE    3758
# SHOW     2047
# Name: title, dtype: int64

# %%
data['release']=data['release_year']>2010

# %%
data['release']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5801     True
# 5802     True
# 5803     True
# 5804     True
# 5805     True
# Name: release, Length: 5806, dtype: bool

# %%
sns.barplot(x='release',y='imdb_votes',data=data)
plt.title("laaaa")
plt.show()
