# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\udemy_courses.csv")

# %%
# 1. Display Top 10 Rows of The Dataset
data.head(10)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5    1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6    1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7     768028  * An Integrated Approach to the Fundamentals o...     True
# 8     206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9     738910  [Value Investing] Where White People Keep Thei...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# ...

# %%
### 2. Check Last 10 Rows of The Dataset
data.tail(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 3675    1031698                        You Can Play Jazz Saxophone     True
# 3676      79364                       Your Business by the Numbers     True
# 3677    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3678     551170                         Your First Course on Piano     True
# 3679     498488  Your First Successful Forex Trades - With Case...     True
# 3680     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3681     552700    Your Second Course on Piano: Two Handed Playing     True
# 3682     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3683    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3684     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print('No of row',data.shape[0])
print('No of column',data.shape[1])
# Out:
# No of row 3685
# No of column 11

# %%
### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3685 non-null   int64
#  1   course_title         3685 non-null   object
#  2   is_paid              3685 non-null   bool
#  3   price                3685 non-null   object
#  4   num_subscribers      3685 non-null   int64
#  5   num_reviews          3685 non-null   int64
#  6   num_lectures         3685 non-null   int64
#  7   level                3685 non-null   object
#  8   content_duration     3685 non-null   object
#  9   published_timestamp  3685 non-null   object
#  10  subject              3685 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.6+ KB

# %%
### 5. Check Missing Values In The Dataset
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
### 6. Drop All The  Missing Values
data.dropna(how='any',inplace=False)
#no null values
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3680     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3681     552700    Your Second Course on Piano: Two Handed Playing     True
# 3682     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3683    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3684     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
### 7. Check For Duplicate Data
dup=data.duplicated().any()
#whole row is similar in multiple places check by duplicated() function
print('any dupli value',dup)
# Out:
# any dupli value True
