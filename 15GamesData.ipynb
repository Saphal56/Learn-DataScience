# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\games_data.csv',encoding = 'unicode_escape')
# Out:
# C:\Users\raisu\AppData\Local\Temp\ipykernel_18036\3436044620.py:1: DtypeWarning: Columns (0,10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('C:\\games_data.csv',encoding = 'unicode_escape')

# %%
data.head(20)
# Out:
#     id                              title release_date  \
# 0    0   Counter-Strike: Global Offensive   2012-08-21
# 1    1                             Dota 2   2013-07-09
# 2    2         Warhammer 40,000: Darktide          NaN
# 3    3  Call of Duty®: Modern Warfare® II          NaN
# 4    4                      Apex Legends          NaN
# 5    5                PUBG: BATTLEGROUNDS          NaN
# 6    6                 NARAKA: BLADEPOINT          NaN
# 7    7                   Dead by Daylight   2016-06-14
# 8    8                           Warframe   2013-03-25
# 9    9                        War Thunder   2013-08-15
# 10  10                 EA SPORTS FIFA 23          NaN
# 11  11                 Grand Theft Auto V   2015-04-13
# 12  12              Football Manager 2023          NaN
# 13  13                         ELDEN RING          NaN
# 14  14          The Elder Scrolls® Online   2017-05-22
# 15  15                          Destiny 2          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73345 entries, 0 to 73344
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           73341 non-null  object
#  1   title                        73341 non-null  object
#  2   release_date                 23281 non-null  object
#  3   developer                    23281 non-null  object
#  4   publisher                    23281 non-null  object
#  5   genres                       23281 non-null  object
#  6   multiplayer_or_singleplayer  23281 non-null  object
#  7   price                        73340 non-null  object
#  8   dc_price                     73340 non-null  object
#  9   overall_review               36875 non-null  object
#  10  detailed_review              36865 non-null  object
#  11  reviews                      36865 non-null  object
#  12  percent_positive             36865 non-null  object
# ...

# %%
sns.displot(data['lin_support'],kde=False,bins=100,aspect=2)

# %%
data_drop=data.drop(columns=['publisher'],axis=1)

# %%
data_drop.drop([0,1],axis=0)
# Out:
#             id                              title release_date developer  \
# 2            2         Warhammer 40,000: Darktide          NaN       NaN
# 3            3  Call of Duty®: Modern Warfare® II          NaN       NaN
# 4            4                      Apex Legends          NaN       NaN
# 5            5                PUBG: BATTLEGROUNDS          NaN       NaN
# 6            6                 NARAKA: BLADEPOINT          NaN       NaN
# ...        ...                                ...          ...       ...
# 73340  73339.0                   Pirate Commander          NaN       NaN
# 73341  73340.0                       Fairy Bubble          NaN       NaN
# 73342  73341.0                    Criminal Russia          NaN       NaN
# 73343  73342.0                     Carmine Impact          NaN       NaN
# 73344  73343.0              Artifice: War Tactics          NaN       NaN
#
#       genres multiplayer_or_singleplayer         price      dc_price  \
# ...

# %%
data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73345 entries, 0 to 73344
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           73341 non-null  object
#  1   title                        73341 non-null  object
#  2   release_date                 23281 non-null  object
#  3   developer                    23281 non-null  object
#  4   genres                       23281 non-null  object
#  5   multiplayer_or_singleplayer  23281 non-null  object
#  6   price                        73340 non-null  object
#  7   dc_price                     73340 non-null  object
#  8   overall_review               36875 non-null  object
#  9   detailed_review              36865 non-null  object
#  10  reviews                      36865 non-null  object
#  11  percent_positive             36865 non-null  object
#  12  win_support                  73335 non-null  object
# ...

# %%
data=data_drop

# %%
data
# Out:
#             id                              title release_date  \
# 0            0   Counter-Strike: Global Offensive   2012-08-21
# 1            1                             Dota 2   2013-07-09
# 2            2         Warhammer 40,000: Darktide          NaN
# 3            3  Call of Duty®: Modern Warfare® II          NaN
# 4            4                      Apex Legends          NaN
# ...        ...                                ...          ...
# 73340  73339.0                   Pirate Commander          NaN
# 73341  73340.0                       Fairy Bubble          NaN
# 73342  73341.0                    Criminal Russia          NaN
# 73343  73342.0                     Carmine Impact          NaN
# 73344  73343.0              Artifice: War Tactics          NaN
#
#                              developer                        genres  \
# 0      Valve;Hidden Path Entertainment           Action;Free to Play
# ...
